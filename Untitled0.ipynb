# %% [markdown]
# <a href="https://colab.research.google.com/github/hieunguyencong011-hash/BT-NH-M-KIA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import PIL.Image
import tensorflow as tf
import google.colab.files as files
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# 1. Tải và cấu hình đường dẫn chuẩn
dataset_url = "/content/drive/MyDrive/flower_photos"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir) / "flower_photos"

class_names = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
img_height, img_width, batch_size = 180, 180, 32

# 2. Nạp dữ liệu
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir, validation_split=0.2, subset="training", seed=123,
  image_size=(img_height, img_width), batch_size=batch_size, class_names=class_names
)
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir, validation_split=0.2, subset="validation", seed=123,
  image_size=(img_height, img_width), batch_size=batch_size, class_names=class_names
)

# Tăng cường hiệu suất đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# 3. XÂY DỰNG MÔ HÌNH CNN ĐA TẦNG (Thông minh hơn phiên bản cũ rất nhiều)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Dropout(0.2), # Chống học vẹt
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(5)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# 4. CHO AI HỌC KỸ 10 VÒNG (Mất khoảng 30-40 giây để thông não)
print("-> Đang tiến hành huấn luyện kỹ lưỡng (10 vòng)...")
model.fit(train_ds, validation_data=val_ds, epochs=10)
print("-> AI đã tốt nghiệp loại giỏi!")

# 5. Tải ảnh lên kiểm tra lại
print("\n=== NHẬP ẢNH HOA CỦA BẠN VÀO ĐÂY ===")
uploaded = files.upload()

for fn in uploaded.keys():
  img = PIL.Image.open(fn)

  plt.figure(figsize=(4, 4))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img_resized = img.resize((img_height, img_width))
  img_array = tf.keras.utils.img_to_array(img_resized)
  img_array = tf.expand_dims(img_array, 0)

  predictions = model.predict(img_array)
  score = tf.nn.softmax(predictions[0])

  print(f"\n[KẾT QUẢ DỰ ĐOÁN]: Đây là hoa **{class_names[np.argmax(score)]}**")
  print(f"[ĐỘ TỰ TIN CỦA AI]: {100 * np.max(score):.2f}%")
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# -> Đang tiến hành huấn luyện kỹ lưỡng (10 vòng)...
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 62ms/step - accuracy: 0.3958 - loss: 1.3872 - val_accuracy: 0.5586 - val_loss: 1.0471
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5981 - loss: 1.0111 - val_accuracy: 0.5954 - val_loss: 1.0223
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6754 - loss: 0.8480 - val_accuracy: 0.6390 - val_loss: 0.9101
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7330 - loss: 0.6836 - val_accuracy: 0.6567 - val_loss: 0.8882
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8297 - loss: 0.4830 - val_accuracy: 0.6540 - val_loss: 0.9660
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8910 - loss: 0.3137 - val_accuracy: 0.6553 - val_loss: 1.1502
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
